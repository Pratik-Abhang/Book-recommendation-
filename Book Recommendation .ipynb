# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
import pandas as pd 
import numpy as np

# %%
book = pd.read_csv("Books.csv")
rating = pd.read_csv("Ratings.csv")
user = pd.read_csv("Users.csv")
# Out:
# C:\Users\PRATIK\AppData\Local\Temp\ipykernel_4748\3934456260.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   book = pd.read_csv("Books.csv")

# %%
book
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# 1       Richard Bruce Wright                2001
# 2               Carlo D'Este                1991
# 3           Gina Bari Kolata                1999
# 4            E. J. W. Barber                1999
# ...                      ...                 ...
# 271355        Paula Danziger                1988
# 271356            Teri Sloat                1991
# 271357      Christine Wicker                2004
# 271358                 Plato                1996
# 271359   Christopher  Biffle                2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
# [271360 rows x 8 columns]

# %%
rating
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
user
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
rating['User-ID'].value_counts()
# Out:
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: User-ID, Length: 105283, dtype: int64

# %%
rating['User-ID'].unique().shape
# Out:
# (105283,)

# %%
x = rating['User-ID'].value_counts() > 100

# %%
x[x].shape
# Out:
# (1825,)

# %%
y = x[x].index
y
# Out:
# Int64Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352,
#             110973, 235105,
#             ...
#             238186,  99441, 187410, 262070,  70183,  40553,  39345, 266283,
#             189666, 140879],
#            dtype='int64', length=1825)

# %%
rating = rating[rating['User-ID'].isin(y)]

# %%
rating
# Out:
#          User-ID        ISBN  Book-Rating
# 412       276925  0006511929            0
# 413       276925  002542730X           10
# 414       276925  0060520507            0
# 415       276925  0060930934            0
# 416       276925  0060951303            0
# ...          ...         ...          ...
# 1149633   276680  1884910033            0
# 1149634   276680  1888173408            7
# 1149635   276680  1888173564            8
# 1149636   276680  1888173572            0
# 1149637   276680  1931561648            9
#
# [656605 rows x 3 columns]

# %%
books_ratings = rating.merge(book,on='ISBN')

# %%
books_ratings
# Out:
#         User-ID        ISBN  Book-Rating  \
# 0        276925  002542730X           10
# 1        277427  002542730X           10
# 2          3363  002542730X            0
# 3         10030  002542730X            7
# 4         11676  002542730X            6
# ...         ...         ...          ...
# 604849   276680  089587167X            7
# 604850   276680  1402201435            4
# 604851   276680  1564407284            0
# 604852   276680  1582343594            0
# 604853   276680  1888173408            7
#
#                                                Book-Title  \
# 0       Politically Correct Bedtime Stories: Modern Ta...
# 1       Politically Correct Bedtime Stories: Modern Ta...
# 2       Politically Correct Bedtime Stories: Modern Ta...
# 3       Politically Correct Bedtime Stories: Modern Ta...
# 4       Politically Correct Bedtime Stories: Modern Ta...
# ...                                                   ...
# 604849                                     Something Blue
# 604850                                 The One True Ocean
# 604851  The Old Sturbridge Village Cookbook, 2nd : Aut...
# 604852                 City of Masks : A Cree Black Novel
# 604853                Fairy Tale (Common Reader Editions)
#
#                     Book-Author Year-Of-Publication  \
# 0             James Finn Garner                1994
# 1             James Finn Garner                1994
# 2             James Finn Garner                1994
# 3             James Finn Garner                1994
# 4             James Finn Garner                1994
# ...                         ...                 ...
# 604849  Jean Christopher Spaugh                1997
# 604850        Sarah Beth Martin                2003
# 604851           Caroline Sloat                1995
# 604852             Daniel Hecht                2004
# 604853       Alice Thomas Ellis                2001
#
#                         Publisher  \
# 0       John Wiley &amp; Sons Inc
# 1       John Wiley &amp; Sons Inc
# 2       John Wiley &amp; Sons Inc
# 3       John Wiley &amp; Sons Inc
# 4       John Wiley &amp; Sons Inc
# ...                           ...
# 604849    John F. Blair Publisher
# 604850       Sourcebooks Landmark
# 604851               Globe Pequot
# 604852             Bloomsbury USA
# 604853              Akadine Press
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/002542730X.0...
# 1       http://images.amazon.com/images/P/002542730X.0...
# 2       http://images.amazon.com/images/P/002542730X.0...
# 3       http://images.amazon.com/images/P/002542730X.0...
# 4       http://images.amazon.com/images/P/002542730X.0...
# ...                                                   ...
# 604849  http://images.amazon.com/images/P/089587167X.0...
# 604850  http://images.amazon.com/images/P/1402201435.0...
# 604851  http://images.amazon.com/images/P/1564407284.0...
# 604852  http://images.amazon.com/images/P/1582343594.0...
# 604853  http://images.amazon.com/images/P/1888173408.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/002542730X.0...
# 1       http://images.amazon.com/images/P/002542730X.0...
# 2       http://images.amazon.com/images/P/002542730X.0...
# 3       http://images.amazon.com/images/P/002542730X.0...
# 4       http://images.amazon.com/images/P/002542730X.0...
# ...                                                   ...
# 604849  http://images.amazon.com/images/P/089587167X.0...
# 604850  http://images.amazon.com/images/P/1402201435.0...
# 604851  http://images.amazon.com/images/P/1564407284.0...
# 604852  http://images.amazon.com/images/P/1582343594.0...
# 604853  http://images.amazon.com/images/P/1888173408.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/002542730X.0...
# 1       http://images.amazon.com/images/P/002542730X.0...
# 2       http://images.amazon.com/images/P/002542730X.0...
# 3       http://images.amazon.com/images/P/002542730X.0...
# 4       http://images.amazon.com/images/P/002542730X.0...
# ...                                                   ...
# 604849  http://images.amazon.com/images/P/089587167X.0...
# 604850  http://images.amazon.com/images/P/1402201435.0...
# 604851  http://images.amazon.com/images/P/1564407284.0...
# 604852  http://images.amazon.com/images/P/1582343594.0...
# 604853  http://images.amazon.com/images/P/1888173408.0...
#
# [604854 rows x 10 columns]

# %%
num_rating = books_ratings.groupby('Book-Title')['Book-Rating'].count().reset_index()

# %%
num_rating
# Out:
#                                                Book-Title  Book-Rating
# 0        A Light in the Storm: The Civil War Diary of ...            3
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Beyond IBM: Leadership Marketing and Finance ...            1
# 4        Clifford Visita El Hospital (Clifford El Gran...            1
# ...                                                   ...          ...
# 182179                   Ã?Â?berraschung am Valentinstag.            1
# 182180                                      Ã?Â?lpiraten.            1
# 182181                     Ã?Â?rger mit Produkt X. Roman.            2
# 182182                              Ã?Â?stlich der Berge.            1
# 182183                                  Ã?Â?thique en toc            2
#
# [182184 rows x 2 columns]

# %%
num_rating.rename(columns={'Book-Rating':'No_of_ratings'},inplace=True)

# %%
num_rating
# Out:
#                                                Book-Title  No_of_ratings
# 0        A Light in the Storm: The Civil War Diary of ...              3
# 1                                   Always Have Popsicles              1
# 2                    Apple Magic (The Collector's series)              1
# 3        Beyond IBM: Leadership Marketing and Finance ...              1
# 4        Clifford Visita El Hospital (Clifford El Gran...              1
# ...                                                   ...            ...
# 182179                   Ã?Â?berraschung am Valentinstag.              1
# 182180                                      Ã?Â?lpiraten.              1
# 182181                     Ã?Â?rger mit Produkt X. Roman.              2
# 182182                              Ã?Â?stlich der Berge.              1
# 182183                                  Ã?Â?thique en toc              2
#
# [182184 rows x 2 columns]

# %%
final_rating = books_ratings.merge(num_rating,on = 'Book-Title')

# %%
final_rating
# Out:
#         User-ID        ISBN  Book-Rating  \
# 0        276925  002542730X           10
# 1        277427  002542730X           10
# 2          3363  002542730X            0
# 3         10030  002542730X            7
# 4         11676  002542730X            6
# ...         ...         ...          ...
# 604849   276680  089587167X            7
# 604850   276680  1402201435            4
# 604851   276680  1564407284            0
# 604852   276680  1582343594            0
# 604853   276680  1888173408            7
#
#                                                Book-Title  \
# 0       Politically Correct Bedtime Stories: Modern Ta...
# 1       Politically Correct Bedtime Stories: Modern Ta...
# 2       Politically Correct Bedtime Stories: Modern Ta...
# 3       Politically Correct Bedtime Stories: Modern Ta...
# 4       Politically Correct Bedtime Stories: Modern Ta...
# ...                                                   ...
# 604849                                     Something Blue
# 604850                                 The One True Ocean
# 604851  The Old Sturbridge Village Cookbook, 2nd : Aut...
# 604852                 City of Masks : A Cree Black Novel
# 604853                Fairy Tale (Common Reader Editions)
#
#                     Book-Author Year-Of-Publication  \
# 0             James Finn Garner                1994
# 1             James Finn Garner                1994
# 2             James Finn Garner                1994
# 3             James Finn Garner                1994
# 4             James Finn Garner                1994
# ...                         ...                 ...
# 604849  Jean Christopher Spaugh                1997
# 604850        Sarah Beth Martin                2003
# 604851           Caroline Sloat                1995
# 604852             Daniel Hecht                2004
# 604853       Alice Thomas Ellis                2001
#
#                         Publisher  \
# 0       John Wiley &amp; Sons Inc
# 1       John Wiley &amp; Sons Inc
# 2       John Wiley &amp; Sons Inc
# 3       John Wiley &amp; Sons Inc
# 4       John Wiley &amp; Sons Inc
# ...                           ...
# 604849    John F. Blair Publisher
# 604850       Sourcebooks Landmark
# 604851               Globe Pequot
# 604852             Bloomsbury USA
# 604853              Akadine Press
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/002542730X.0...
# 1       http://images.amazon.com/images/P/002542730X.0...
# 2       http://images.amazon.com/images/P/002542730X.0...
# 3       http://images.amazon.com/images/P/002542730X.0...
# 4       http://images.amazon.com/images/P/002542730X.0...
# ...                                                   ...
# 604849  http://images.amazon.com/images/P/089587167X.0...
# 604850  http://images.amazon.com/images/P/1402201435.0...
# 604851  http://images.amazon.com/images/P/1564407284.0...
# 604852  http://images.amazon.com/images/P/1582343594.0...
# 604853  http://images.amazon.com/images/P/1888173408.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/002542730X.0...
# 1       http://images.amazon.com/images/P/002542730X.0...
# 2       http://images.amazon.com/images/P/002542730X.0...
# 3       http://images.amazon.com/images/P/002542730X.0...
# 4       http://images.amazon.com/images/P/002542730X.0...
# ...                                                   ...
# 604849  http://images.amazon.com/images/P/089587167X.0...
# 604850  http://images.amazon.com/images/P/1402201435.0...
# 604851  http://images.amazon.com/images/P/1564407284.0...
# 604852  http://images.amazon.com/images/P/1582343594.0...
# 604853  http://images.amazon.com/images/P/1888173408.0...
#
#                                               Image-URL-L  No_of_ratings
# 0       http://images.amazon.com/images/P/002542730X.0...            105
# 1       http://images.amazon.com/images/P/002542730X.0...            105
# 2       http://images.amazon.com/images/P/002542730X.0...            105
# 3       http://images.amazon.com/images/P/002542730X.0...            105
# 4       http://images.amazon.com/images/P/002542730X.0...            105
# ...                                                   ...            ...
# 604849  http://images.amazon.com/images/P/089587167X.0...              1
# 604850  http://images.amazon.com/images/P/1402201435.0...              1
# 604851  http://images.amazon.com/images/P/1564407284.0...              1
# 604852  http://images.amazon.com/images/P/1582343594.0...              1
# 604853  http://images.amazon.com/images/P/1888173408.0...              1
#
# [604854 rows x 11 columns]

# %%
final_rating.drop_duplicates(['User-ID','Book-Title'],inplace=True)

# %%
final_rating
# Out:
#         User-ID        ISBN  Book-Rating  \
# 0        276925  002542730X           10
# 1        277427  002542730X           10
# 2          3363  002542730X            0
# 3         10030  002542730X            7
# 4         11676  002542730X            6
# ...         ...         ...          ...
# 604849   276680  089587167X            7
# 604850   276680  1402201435            4
# 604851   276680  1564407284            0
# 604852   276680  1582343594            0
# 604853   276680  1888173408            7
#
#                                                Book-Title  \
# 0       Politically Correct Bedtime Stories: Modern Ta...
# 1       Politically Correct Bedtime Stories: Modern Ta...
# 2       Politically Correct Bedtime Stories: Modern Ta...
# 3       Politically Correct Bedtime Stories: Modern Ta...
# 4       Politically Correct Bedtime Stories: Modern Ta...
# ...                                                   ...
# 604849                                     Something Blue
# 604850                                 The One True Ocean
# 604851  The Old Sturbridge Village Cookbook, 2nd : Aut...
# 604852                 City of Masks : A Cree Black Novel
# 604853                Fairy Tale (Common Reader Editions)
#
#                     Book-Author Year-Of-Publication  \
# 0             James Finn Garner                1994
# 1             James Finn Garner                1994
# 2             James Finn Garner                1994
# 3             James Finn Garner                1994
# 4             James Finn Garner                1994
# ...                         ...                 ...
# 604849  Jean Christopher Spaugh                1997
# 604850        Sarah Beth Martin                2003
# 604851           Caroline Sloat                1995
# 604852             Daniel Hecht                2004
# 604853       Alice Thomas Ellis                2001
#
#                         Publisher  \
# 0       John Wiley &amp; Sons Inc
# 1       John Wiley &amp; Sons Inc
# 2       John Wiley &amp; Sons Inc
# 3       John Wiley &amp; Sons Inc
# 4       John Wiley &amp; Sons Inc
# ...                           ...
# 604849    John F. Blair Publisher
# 604850       Sourcebooks Landmark
# 604851               Globe Pequot
# 604852             Bloomsbury USA
# 604853              Akadine Press
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/002542730X.0...
# 1       http://images.amazon.com/images/P/002542730X.0...
# 2       http://images.amazon.com/images/P/002542730X.0...
# 3       http://images.amazon.com/images/P/002542730X.0...
# 4       http://images.amazon.com/images/P/002542730X.0...
# ...                                                   ...
# 604849  http://images.amazon.com/images/P/089587167X.0...
# 604850  http://images.amazon.com/images/P/1402201435.0...
# 604851  http://images.amazon.com/images/P/1564407284.0...
# 604852  http://images.amazon.com/images/P/1582343594.0...
# 604853  http://images.amazon.com/images/P/1888173408.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/002542730X.0...
# 1       http://images.amazon.com/images/P/002542730X.0...
# 2       http://images.amazon.com/images/P/002542730X.0...
# 3       http://images.amazon.com/images/P/002542730X.0...
# 4       http://images.amazon.com/images/P/002542730X.0...
# ...                                                   ...
# 604849  http://images.amazon.com/images/P/089587167X.0...
# 604850  http://images.amazon.com/images/P/1402201435.0...
# 604851  http://images.amazon.com/images/P/1564407284.0...
# 604852  http://images.amazon.com/images/P/1582343594.0...
# 604853  http://images.amazon.com/images/P/1888173408.0...
#
#                                               Image-URL-L  No_of_ratings
# 0       http://images.amazon.com/images/P/002542730X.0...            105
# 1       http://images.amazon.com/images/P/002542730X.0...            105
# 2       http://images.amazon.com/images/P/002542730X.0...            105
# 3       http://images.amazon.com/images/P/002542730X.0...            105
# 4       http://images.amazon.com/images/P/002542730X.0...            105
# ...                                                   ...            ...
# 604849  http://images.amazon.com/images/P/089587167X.0...              1
# 604850  http://images.amazon.com/images/P/1402201435.0...              1
# 604851  http://images.amazon.com/images/P/1564407284.0...              1
# 604852  http://images.amazon.com/images/P/1582343594.0...              1
# 604853  http://images.amazon.com/images/P/1888173408.0...              1
#
# [600353 rows x 11 columns]

# %%
book_pivot = final_rating.pivot_table(columns='User-ID',index='Book-Title',values='Book-Rating')

# %%
book_pivot
# Out:
# User-ID                                             183     254     507     \
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...     NaN     NaN     NaN
#  Always Have Popsicles                                 NaN     NaN     NaN
#  Apple Magic (The Collector's series)                  NaN     NaN     NaN
#  Beyond IBM: Leadership Marketing and Finance f...     NaN     NaN     NaN
#  Clifford Visita El Hospital (Clifford El Gran ...     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Ã?Â?berraschung am Valentinstag.                       NaN     NaN     NaN
# Ã?Â?lpiraten.                                          NaN     NaN     NaN
# Ã?Â?rger mit Produkt X. Roman.                         NaN     NaN     NaN
# Ã?Â?stlich der Berge.                                  NaN     NaN     NaN
# Ã?Â?thique en toc                                      NaN     NaN     NaN
#
# User-ID                                             882     1424    1435    \
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...     NaN     NaN     NaN
#  Always Have Popsicles                                 NaN     NaN     NaN
#  Apple Magic (The Collector's series)                  NaN     NaN     NaN
#  Beyond IBM: Leadership Marketing and Finance f...     NaN     NaN     NaN
#  Clifford Visita El Hospital (Clifford El Gran ...     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Ã?Â?berraschung am Valentinstag.                       NaN     NaN     NaN
# Ã?Â?lpiraten.                                          NaN     NaN     NaN
# Ã?Â?rger mit Produkt X. Roman.                         NaN     NaN     NaN
# Ã?Â?stlich der Berge.                                  NaN     NaN     NaN
# Ã?Â?thique en toc                                      NaN     NaN     NaN
#
# User-ID                                             1733    1903    2033    \
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...     NaN     NaN     NaN
#  Always Have Popsicles                                 NaN     NaN     NaN
#  Apple Magic (The Collector's series)                  NaN     NaN     NaN
#  Beyond IBM: Leadership Marketing and Finance f...     NaN     NaN     NaN
#  Clifford Visita El Hospital (Clifford El Gran ...     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Ã?Â?berraschung am Valentinstag.                       NaN     NaN     NaN
# Ã?Â?lpiraten.                                          NaN     NaN     NaN
# Ã?Â?rger mit Produkt X. Roman.                         NaN     NaN     NaN
# Ã?Â?stlich der Berge.                                  NaN     NaN     NaN
# Ã?Â?thique en toc                                      NaN     NaN     NaN
#
# User-ID                                             2110    ...  276463  \
# Book-Title                                                  ...
#  A Light in the Storm: The Civil War Diary of A...     NaN  ...     NaN
#  Always Have Popsicles                                 NaN  ...     NaN
#  Apple Magic (The Collector's series)                  NaN  ...     NaN
#  Beyond IBM: Leadership Marketing and Finance f...     NaN  ...     NaN
#  Clifford Visita El Hospital (Clifford El Gran ...     NaN  ...     NaN
# ...                                                    ...  ...     ...
# Ã?Â?berraschung am Valentinstag.                       NaN  ...     NaN
# Ã?Â?lpiraten.                                          NaN  ...     NaN
# Ã?Â?rger mit Produkt X. Roman.                         NaN  ...     NaN
# Ã?Â?stlich der Berge.                                  NaN  ...     NaN
# Ã?Â?thique en toc                                      NaN  ...     NaN
#
# User-ID                                             276538  276680  276925  \
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...     NaN     NaN     NaN
#  Always Have Popsicles                                 NaN     NaN     NaN
#  Apple Magic (The Collector's series)                  NaN     NaN     NaN
#  Beyond IBM: Leadership Marketing and Finance f...     NaN     NaN     NaN
#  Clifford Visita El Hospital (Clifford El Gran ...     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Ã?Â?berraschung am Valentinstag.                       NaN     NaN     NaN
# Ã?Â?lpiraten.                                          NaN     NaN     NaN
# Ã?Â?rger mit Produkt X. Roman.                         NaN     NaN     NaN
# Ã?Â?stlich der Berge.                                  NaN     NaN     NaN
# Ã?Â?thique en toc                                      NaN     NaN     NaN
#
# User-ID                                             277427  277478  277639  \
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...     NaN     NaN     NaN
#  Always Have Popsicles                                 NaN     NaN     NaN
#  Apple Magic (The Collector's series)                  NaN     NaN     NaN
#  Beyond IBM: Leadership Marketing and Finance f...     NaN     NaN     NaN
#  Clifford Visita El Hospital (Clifford El Gran ...     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Ã?Â?berraschung am Valentinstag.                       NaN     NaN     NaN
# Ã?Â?lpiraten.                                          NaN     NaN     NaN
# Ã?Â?rger mit Produkt X. Roman.                         NaN     NaN     NaN
# Ã?Â?stlich der Berge.                                  NaN     NaN     NaN
# Ã?Â?thique en toc                                      NaN     NaN     NaN
#
# User-ID                                             278137  278188  278418
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...     NaN     NaN     NaN
#  Always Have Popsicles                                 NaN     NaN     NaN
#  Apple Magic (The Collector's series)                  NaN     NaN     NaN
#  Beyond IBM: Leadership Marketing and Finance f...     NaN     NaN     NaN
#  Clifford Visita El Hospital (Clifford El Gran ...     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Ã?Â?berraschung am Valentinstag.                       NaN     NaN     NaN
# Ã?Â?lpiraten.                                          NaN     NaN     NaN
# Ã?Â?rger mit Produkt X. Roman.                         NaN     NaN     NaN
# Ã?Â?stlich der Berge.                                  NaN     NaN     NaN
# Ã?Â?thique en toc                                      NaN     NaN     NaN
#
# [182184 rows x 1825 columns]

# %%
book_pivot.shape
# Out:
# (182184, 1825)

# %%
book_pivot.fillna(0,inplace=True)

# %%
book_pivot
# Out:
# User-ID                                             183     254     507     \
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...     0.0     0.0     0.0
#  Always Have Popsicles                                 0.0     0.0     0.0
#  Apple Magic (The Collector's series)                  0.0     0.0     0.0
#  Beyond IBM: Leadership Marketing and Finance f...     0.0     0.0     0.0
#  Clifford Visita El Hospital (Clifford El Gran ...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Ã?Â?berraschung am Valentinstag.                       0.0     0.0     0.0
# Ã?Â?lpiraten.                                          0.0     0.0     0.0
# Ã?Â?rger mit Produkt X. Roman.                         0.0     0.0     0.0
# Ã?Â?stlich der Berge.                                  0.0     0.0     0.0
# Ã?Â?thique en toc                                      0.0     0.0     0.0
#
# User-ID                                             882     1424    1435    \
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...     0.0     0.0     0.0
#  Always Have Popsicles                                 0.0     0.0     0.0
#  Apple Magic (The Collector's series)                  0.0     0.0     0.0
#  Beyond IBM: Leadership Marketing and Finance f...     0.0     0.0     0.0
#  Clifford Visita El Hospital (Clifford El Gran ...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Ã?Â?berraschung am Valentinstag.                       0.0     0.0     0.0
# Ã?Â?lpiraten.                                          0.0     0.0     0.0
# Ã?Â?rger mit Produkt X. Roman.                         0.0     0.0     0.0
# Ã?Â?stlich der Berge.                                  0.0     0.0     0.0
# Ã?Â?thique en toc                                      0.0     0.0     0.0
#
# User-ID                                             1733    1903    2033    \
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...     0.0     0.0     0.0
#  Always Have Popsicles                                 0.0     0.0     0.0
#  Apple Magic (The Collector's series)                  0.0     0.0     0.0
#  Beyond IBM: Leadership Marketing and Finance f...     0.0     0.0     0.0
#  Clifford Visita El Hospital (Clifford El Gran ...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Ã?Â?berraschung am Valentinstag.                       0.0     0.0     0.0
# Ã?Â?lpiraten.                                          0.0     0.0     0.0
# Ã?Â?rger mit Produkt X. Roman.                         0.0     0.0     0.0
# Ã?Â?stlich der Berge.                                  0.0     0.0     0.0
# Ã?Â?thique en toc                                      0.0     0.0     0.0
#
# User-ID                                             2110    ...  276463  \
# Book-Title                                                  ...
#  A Light in the Storm: The Civil War Diary of A...     0.0  ...     0.0
#  Always Have Popsicles                                 0.0  ...     0.0
#  Apple Magic (The Collector's series)                  0.0  ...     0.0
#  Beyond IBM: Leadership Marketing and Finance f...     0.0  ...     0.0
#  Clifford Visita El Hospital (Clifford El Gran ...     0.0  ...     0.0
# ...                                                    ...  ...     ...
# Ã?Â?berraschung am Valentinstag.                       0.0  ...     0.0
# Ã?Â?lpiraten.                                          0.0  ...     0.0
# Ã?Â?rger mit Produkt X. Roman.                         0.0  ...     0.0
# Ã?Â?stlich der Berge.                                  0.0  ...     0.0
# Ã?Â?thique en toc                                      0.0  ...     0.0
#
# User-ID                                             276538  276680  276925  \
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...     0.0     0.0     0.0
#  Always Have Popsicles                                 0.0     0.0     0.0
#  Apple Magic (The Collector's series)                  0.0     0.0     0.0
#  Beyond IBM: Leadership Marketing and Finance f...     0.0     0.0     0.0
#  Clifford Visita El Hospital (Clifford El Gran ...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Ã?Â?berraschung am Valentinstag.                       0.0     0.0     0.0
# Ã?Â?lpiraten.                                          0.0     0.0     0.0
# Ã?Â?rger mit Produkt X. Roman.                         0.0     0.0     0.0
# Ã?Â?stlich der Berge.                                  0.0     0.0     0.0
# Ã?Â?thique en toc                                      0.0     0.0     0.0
#
# User-ID                                             277427  277478  277639  \
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...     0.0     0.0     0.0
#  Always Have Popsicles                                 0.0     0.0     0.0
#  Apple Magic (The Collector's series)                  0.0     0.0     0.0
#  Beyond IBM: Leadership Marketing and Finance f...     0.0     0.0     0.0
#  Clifford Visita El Hospital (Clifford El Gran ...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Ã?Â?berraschung am Valentinstag.                       0.0     0.0     0.0
# Ã?Â?lpiraten.                                          0.0     0.0     0.0
# Ã?Â?rger mit Produkt X. Roman.                         0.0     0.0     0.0
# Ã?Â?stlich der Berge.                                  0.0     0.0     0.0
# Ã?Â?thique en toc                                      0.0     0.0     0.0
#
# User-ID                                             278137  278188  278418
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...     0.0     0.0     0.0
#  Always Have Popsicles                                 0.0     0.0     0.0
#  Apple Magic (The Collector's series)                  0.0     0.0     0.0
#  Beyond IBM: Leadership Marketing and Finance f...     0.0     0.0     0.0
#  Clifford Visita El Hospital (Clifford El Gran ...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Ã?Â?berraschung am Valentinstag.                       0.0     0.0     0.0
# Ã?Â?lpiraten.                                          0.0     0.0     0.0
# Ã?Â?rger mit Produkt X. Roman.                         0.0     0.0     0.0
# Ã?Â?stlich der Berge.                                  0.0     0.0     0.0
# Ã?Â?thique en toc                                      0.0     0.0     0.0
#
# [182184 rows x 1825 columns]

# %%
from scipy.sparse import csc_matrix

# %%
book_sparse = csc_matrix(book_pivot)

# %%
book_sparse
# Out:
# <182184x1825 sparse matrix of type '<class 'numpy.float64'>'
# 	with 163410 stored elements in Compressed Sparse Column format>

# %%
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(algorithm='brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distance , suggestion = model.kneighbors(book_pivot.iloc[3,:].values.reshape(1,-1),n_neighbors=6)

# %%
distance
# Out:
# array([[0., 0., 0., 0., 0., 0.]])

# %%
suggestion
# Out:
# array([[ 2,  3,  4, 10,  6,  1]], dtype=int64)

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index([' Apple Magic (The Collector's series)',
#        ' Beyond IBM: Leadership Marketing and Finance for the 1990s',
#        ' Clifford Visita El Hospital (Clifford El Gran Perro Colorado)',
#        ' Garfield Bigger and Better (Garfield (Numbered Paperback))',
#        ' Deceived', ' Always Have Popsicles'],
#       dtype='object', name='Book-Title')

# %%
book_pivot.index[3]
# Out:
# ' Beyond IBM: Leadership Marketing and Finance for the 1990s'

# %%
book_name = book_pivot.index

# %%
import os
import pickle

# Create the 'Book_Recommender' directory if it doesn't exist
if not os.path.exists('Book_Recommender'):
    os.makedirs('Book_Recommender')

# Save the files in the 'Book_Recommender' directory
pickle.dump(model, open('Book_Recommender/model.pkl', 'wb'))
pickle.dump(book_name, open('Book_Recommender/book_name.pkl', 'wb'))
pickle.dump(final_rating, open('Book_Recommender/final_rating.pkl', 'wb'))
pickle.dump(book_pivot, open('Book_Recommender/book_pivot.pkl', 'wb'))

# %%
def book_recommend(book_name):
    book_id = np.where(book_pivot.index == book_name)[0][0]
    distance , suggestion = model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1),n_neighbors=6)
    
    for i in range(len(suggestion)):
        books =  book_pivot.index[suggestion[i]]
        for j in books:
            print(j)

# %%
book_name = 'Something Blue'
book_recommend(book_name)
# Out:
# A MARRIAGE MADE AT WOODSTOCK
# Object Lessons (Ballantine Reader's Circle)
# Talking to the Dead : A Novel Tag: Winner of the Orange Prize
# FUNERAL MAKERS
# In a Dark Wood: A Novel
# Fairy Tale (Common Reader Editions)
